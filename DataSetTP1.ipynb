# %% [markdown]
# <a href="https://colab.research.google.com/github/rociotarda/TP1---Datos/blob/main/DataSetTP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-134a0a63-ead5-4a04-8ef3-1ea60a6b4d2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-134a0a63-ead5-4a04-8ef3-1ea60a6b4d2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_labels.csv to train_labels.csv
# Saving train_values.csv to train_values.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import io
  
train_labels = pd.read_csv(io.BytesIO(uploaded['train_labels.csv']))
train_labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
train_values = pd.read_csv(io.BytesIO(uploaded['train_values.csv']))
train_values.head()
# Out:
#    building_id  ...  has_secondary_use_other
# 0       802906  ...                        0
# 1        28830  ...                        0
# 2        94947  ...                        0
# 3       590882  ...                        0
# 4       201944  ...                        0
#
# [5 rows x 39 columns]
